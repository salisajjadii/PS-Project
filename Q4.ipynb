# %% [markdown]
# # Project - Statistics and Probability

# %% [markdown]
# ### Instructor: Dr. Yassaee

# %% [markdown]
# ### Seyed Ali Sajjadi - 401101813
#
# ### Mahdi Gholizade kalan - 401102337

# %% [markdown]
# Simulation Question 4:

# %%
import random
import matplotlib.pyplot as plt

mList = [-1, 1]
data = []
loc = 0
zoo = 0
park = 0
for j in range(0, 100000):
    for i in range(0, 10000):
        loc += random.choice(mList)
        if loc == -1:
            park += 1
            data.append("Park")
            break
        if loc == 2:
            zoo += 1
            data.append("Zoo")
            break
    loc = 0

pZoo = zoo/100000
pPark = park/100000

plt.hist(data, color='gray')
plt.xlabel(f"P(zoo) = {pZoo}            P(park) = {pPark}")
plt.ylabel('Frequency')
plt.show()
