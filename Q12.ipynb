# %% [markdown]
# # Project - Statistics and Probability

# %% [markdown]
# ### Instructor: Dr. Yassaee

# %% [markdown]
# ### Seyed Ali Sajjadi - 401101813
#
# ### Mahdi Gholizade kalan - 401102337

# %% [markdown]
# Simulation Question 12:

# %% [markdown]
# Part1:

# %%
import numpy as np
import matplotlib.pyplot as plt

locations = []
cLoc = 0
for i in range(0, 10000):
    y = np.random.exponential(1)
    cLoc += y
    locations.append(cLoc)

plt.scatter(np.linspace(0, 10000, 10000), locations, color='gray', edgecolors='black')
plt.title(f'Final position is {cLoc}')
plt.xlabel('Steps        (movings ~ gamma(0, 1) = exponential(1))')
plt.ylabel('Current Position')
plt.show()

# %% [markdown]
# Part2:

# %%
import numpy as np
import matplotlib.pyplot as plt

locations1 = []
cLoc1 = 0
for i in range(0, 1000):
    y = np.random.exponential(1)
    cLoc1 += y
    locations1.append(cLoc1)

locations2 = []
cLoc2 = 0
for i in range(0, 1000):
    y = np.random.exponential(1)
    cLoc2 += y
    locations2.append(cLoc2)

locations3 = []
cLoc3 = 0
for i in range(0, 1000):
    y = np.random.exponential(1)
    cLoc3 += y
    locations3.append(cLoc3)

locations4 = []
cLoc4 = 0
for i in range(0, 1000):
    y = np.random.exponential(1)
    cLoc4 += y
    locations4.append(cLoc4)

locations5 = []
cLoc5 = 0
for i in range(0, 1000):
    y = np.random.exponential(1)
    cLoc5 += y
    locations5.append(cLoc5) 

plt.scatter(np.linspace(0, 1000, 1000), locations1, color='gray', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations2, color='red', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations3, color='green', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations4, color='blue', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations5, color='purple', edgecolors='black')
plt.title('5 simulations with the N=1000')
plt.xlabel('Steps        (movings ~ gamma(0, 1) = exponential(1))')
plt.ylabel('Current Position')
plt.show()

# %% [markdown]
# Part3:

# %%
import numpy as np
import matplotlib.pyplot as plt

locations1 = []
cLoc1 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 1)
    cLoc1 += y
    locations1.append(cLoc1)

locations2 = []
cLoc2 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 1)
    cLoc2 += y
    locations2.append(cLoc2)

locations3 = []
cLoc3 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 1)
    cLoc3 += y
    locations3.append(cLoc3)

locations4 = []
cLoc4 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 1)
    cLoc4 += y
    locations4.append(cLoc4)

locations5 = []
cLoc5 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 1)
    cLoc5 += y
    locations5.append(cLoc5) 

plt.scatter(np.linspace(0, 1000, 1000), locations1, color='gray', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations2, color='red', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations3, color='green', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations4, color='blue', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations5, color='purple', edgecolors='black')
plt.title('5 simulations with the N=1000')
plt.xlabel('Steps        (movings ~ gamma(2, 1))')
plt.ylabel('Current Position')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

locations1 = []
cLoc1 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 1)
    cLoc1 += y
    locations1.append(cLoc1)

locations2 = []
cLoc2 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 1)
    cLoc2 += y
    locations2.append(cLoc2)

locations3 = []
cLoc3 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 1)
    cLoc3 += y
    locations3.append(cLoc3)

locations4 = []
cLoc4 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 1)
    cLoc4 += y
    locations4.append(cLoc4)

locations5 = []
cLoc5 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 1)
    cLoc5 += y
    locations5.append(cLoc5) 

plt.scatter(np.linspace(0, 1000, 1000), locations1, color='gray', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations2, color='red', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations3, color='green', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations4, color='blue', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations5, color='purple', edgecolors='black')
plt.title('5 simulations with the N=1000')
plt.xlabel('Steps        (movings ~ gamma(3, 1))')
plt.ylabel('Current Position')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

locations1 = []
cLoc1 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 1)
    cLoc1 += y
    locations1.append(cLoc1)

locations2 = []
cLoc2 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 1)
    cLoc2 += y
    locations2.append(cLoc2)

locations3 = []
cLoc3 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 1)
    cLoc3 += y
    locations3.append(cLoc3)

locations4 = []
cLoc4 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 1)
    cLoc4 += y
    locations4.append(cLoc4)

locations5 = []
cLoc5 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 1)
    cLoc5 += y
    locations5.append(cLoc5) 

plt.scatter(np.linspace(0, 1000, 1000), locations1, color='gray', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations2, color='red', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations3, color='green', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations4, color='blue', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations5, color='purple', edgecolors='black')
plt.title('5 simulations with the N=1000')
plt.xlabel('Steps        (movings ~ gamma(4, 1))')
plt.ylabel('Current Position')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

locations1 = []
cLoc1 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 1)
    cLoc1 += y
    locations1.append(cLoc1)

locations2 = []
cLoc2 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 1)
    cLoc2 += y
    locations2.append(cLoc2)

locations3 = []
cLoc3 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 1)
    cLoc3 += y
    locations3.append(cLoc3)

locations4 = []
cLoc4 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 1)
    cLoc4 += y
    locations4.append(cLoc4)

locations5 = []
cLoc5 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 1)
    cLoc5 += y
    locations5.append(cLoc5) 

plt.scatter(np.linspace(0, 1000, 1000), locations1, color='gray', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations2, color='red', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations3, color='green', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations4, color='blue', edgecolors='black')
plt.scatter(np.linspace(0, 1000, 1000), locations5, color='purple', edgecolors='black')
plt.title('5 simulations with the N=1000')
plt.xlabel('Steps        (movings ~ gamma(5, 1))')
plt.ylabel('Current Position')
plt.show()

# %% [markdown]
# Part4:

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 2)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 2)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 2)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 2)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 2)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 2))')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 2)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 2)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 2)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 2)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 2)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 2))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 2)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 2)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 2)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 2)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 2)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 2))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 2)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 2)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 2)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 2)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 2)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 2))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 5)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 5)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 5)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 5)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 5)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 5))')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 5)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 5)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 5)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 5)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 5)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 5))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 5)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 5)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 5)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 5)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 5)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 5))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 5)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 5)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 5)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 5)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 5)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 5))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 10)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 10)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 10)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 10)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 10)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 10))')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 10)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 10)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 10)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 10)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 10)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 10))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 10)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 10)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 10)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 10)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 10)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 10))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 10)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 10)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 10)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 10)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 10)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 10))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 15)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 15)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 15)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 15)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 15)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 15))')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 15)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 15)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 15)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 15)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 15)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 15))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 15)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 15)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 15)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 15)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 15)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 15))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 15)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 15)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 15)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 15)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 15)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 15))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 20)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 20)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 20)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 20)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 20)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 20))')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 20)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 20)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 20)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 20)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 20)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 20))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 20)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 20)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 20)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 20)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 20)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 20))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 20)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 20)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 20)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 20)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 20)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 20))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 25)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 25)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 25)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 25)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 25)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 25))')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 25)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 25)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 25)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 25)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 25)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 25))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 25)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 25)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 25)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 25)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 25)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 25))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 25)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 25)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 25)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 25)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 25)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 25))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 30)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 30)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 30)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 30)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 30)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 30))')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 30)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 30)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 30)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 30)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 30)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 30))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 30)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 30)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 30)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 30)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 30)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 30))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 30)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 30)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 30)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 30)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 30)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 30))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 50)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 50)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 50)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 50)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 50)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 50))')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 50)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 50)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 50)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 50)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 50)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 50))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 50)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 50)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 50)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 50)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 50)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 50))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 50)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 50)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 50)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 50)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 50)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 50))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 75)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 75)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 75)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 75)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 75)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 75)')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 75)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 75)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 75)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 75)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 75)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 75))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 75)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 75)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 75)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 75)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 75)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 75))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 75)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 75)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 75)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 75)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 75)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 75))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 100)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 100)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 100)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 100)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 100)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 100))')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 100)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 100)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 100)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 100)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 100)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 100))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 100)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 100)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 100)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 100)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 100)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 100))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 100)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 100)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 100)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 100)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 100)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 100))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

locations11 = []
cLoc11 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 200)
    cLoc11 += y
    locations11.append(cLoc11)

locations21 = []
cLoc21 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 200)
    cLoc21 += y
    locations21.append(cLoc21)

locations31 = []
cLoc31 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 200)
    cLoc31 += y
    locations31.append(cLoc31)

locations41 = []
cLoc41 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 200)
    cLoc41 += y
    locations41.append(cLoc41)

locations51 = []
cLoc51 = 0
for i in range(0, 1000):
    y = np.random.gamma(2, 200)
    cLoc51 += y
    locations51.append(cLoc51) 

axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations11, color='gray', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations21, color='red', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations31, color='green', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations41, color='blue', edgecolors='black')
axes[0, 0].scatter(np.linspace(0, 1000, 1000), locations51, color='purple', edgecolors='black')
axes[0, 0].set_xlabel('Steps        (movings ~ gamma(2, 200))')
axes[0, 0].set_ylabel('Current Position')

##########################################################################################

locations12 = []
cLoc12 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 200)
    cLoc12 += y
    locations12.append(cLoc12)

locations22 = []
cLoc22 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 200)
    cLoc22 += y
    locations22.append(cLoc22)

locations32 = []
cLoc32 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 200)
    cLoc32 += y
    locations32.append(cLoc32)

locations42 = []
cLoc42 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 200)
    cLoc42 += y
    locations42.append(cLoc42)

locations52 = []
cLoc52 = 0
for i in range(0, 1000):
    y = np.random.gamma(3, 200)
    cLoc52 += y
    locations52.append(cLoc52) 

axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations12, color='gray', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations22, color='red', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations32, color='green', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations42, color='blue', edgecolors='black')
axes[0, 1].scatter(np.linspace(0, 1000, 1000), locations52, color='purple', edgecolors='black')
axes[0, 1].set_xlabel('Steps        (movings ~ gamma(3, 200))')
axes[0, 1].set_ylabel('Current Position')

##########################################################################################

locations13 = []
cLoc13 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 200)
    cLoc13 += y
    locations13.append(cLoc13)

locations23 = []
cLoc23 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 200)
    cLoc23 += y
    locations23.append(cLoc23)

locations33 = []
cLoc33 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 200)
    cLoc33 += y
    locations33.append(cLoc33)

locations43 = []
cLoc43 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 200)
    cLoc43 += y
    locations43.append(cLoc43)

locations53 = []
cLoc53 = 0
for i in range(0, 1000):
    y = np.random.gamma(4, 200)
    cLoc53 += y
    locations53.append(cLoc53) 

axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations13, color='gray', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations23, color='red', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations33, color='green', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations43, color='blue', edgecolors='black')
axes[1, 0].scatter(np.linspace(0, 1000, 1000), locations53, color='purple', edgecolors='black')
axes[1, 0].set_xlabel('Steps        (movings ~ gamma(4, 200))')
axes[1, 0].set_ylabel('Current Position')

##########################################################################################

locations14 = []
cLoc14 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 200)
    cLoc14 += y
    locations14.append(cLoc14)

locations24 = []
cLoc24 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 200)
    cLoc24 += y
    locations24.append(cLoc24)

locations34 = []
cLoc34 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 200)
    cLoc34 += y
    locations34.append(cLoc34)

locations44 = []
cLoc44 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 200)
    cLoc44 += y
    locations44.append(cLoc44)

locations54 = []
cLoc54 = 0
for i in range(0, 1000):
    y = np.random.gamma(5, 200)
    cLoc54 += y
    locations54.append(cLoc54) 

axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations14, color='gray', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations24, color='red', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations34, color='green', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations44, color='blue', edgecolors='black')
axes[1, 1].scatter(np.linspace(0, 1000, 1000), locations54, color='purple', edgecolors='black')
axes[1, 1].set_xlabel('Steps        (movings ~ gamma(5, 200))')
axes[1, 1].set_ylabel('Current Position')

plt.suptitle('5 simulations with the N=1000')
plt.show()
